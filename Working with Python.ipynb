# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel (r'Desktop\Insurance.xlsx')
print (df)
# Out:
#         Column1  Policy     Expiry Location State   Region  InsuredValue  \
# 0   Rahul Kumar  100242 2021-01-02    Urban    NY     East       1617630
# 1   Rohan Singh  100314 2021-01-02    Urban    NY     East       8678500
# 2     Karthik A  100359 2021-01-02    Rural    WI  Midwest       2052660
# 3      Sukesh M  100315 2021-01-03    Urban    NY     East      17580000
# 4      deepak m  100385 2021-01-03    Urban    NY     East       1925000
# ..          ...     ...        ...      ...   ...      ...           ...
# 95    sudeesh r  100467 2021-03-08    Urban    NJ     East       2249500
# 96     Sundar p  100583 2021-03-08    Urban    NY     East       7611000
# 97      Vilas M  100404 2021-03-09    Rural    WI  Midwest       1152600
# 98     Basava P  100554 2021-03-09    Urban    NJ     East       9115500
# 99     Rajesh K  100446 2021-03-11    Urban    NY     East       1600000
#
#    Construction BusinessType Earthquake Flood
# 0         Frame       Retail          N     N
# 1   Fire Resist    Apartment          Y     Y
# 2         Frame      Farming          N     N
# 3         Frame    Apartment          Y     Y
# 4       Masonry  Hospitality          N     N
# ..          ...          ...        ...   ...
# 95        Frame      Farming          N     N
# 96      Masonry  Office Bldg          Y     Y
# 97        Frame      Farming          N     N
# 98        Frame    Apartment          Y     Y
# 99      Masonry  Hospitality          Y     Y
#
# [100 rows x 11 columns]

# %%
df.head()
# Out:
#        Column1  Policy     Expiry Location State   Region  InsuredValue  \
# 0  Rahul Kumar  100242 2021-01-02    Urban    NY     East       1617630
# 1  Rohan Singh  100314 2021-01-02    Urban    NY     East       8678500
# 2    Karthik A  100359 2021-01-02    Rural    WI  Midwest       2052660
# 3     Sukesh M  100315 2021-01-03    Urban    NY     East      17580000
# 4     deepak m  100385 2021-01-03    Urban    NY     East       1925000
#
#   Construction BusinessType Earthquake Flood
# 0        Frame       Retail          N     N
# 1  Fire Resist    Apartment          Y     Y
# 2        Frame      Farming          N     N
# 3        Frame    Apartment          Y     Y
# 4      Masonry  Hospitality          N     N

# %%
df.head(10)
# Out:
#        Column1  Policy     Expiry Location State   Region  InsuredValue  \
# 0  Rahul Kumar  100242 2021-01-02    Urban    NY     East       1617630
# 1  Rohan Singh  100314 2021-01-02    Urban    NY     East       8678500
# 2    Karthik A  100359 2021-01-02    Rural    WI  Midwest       2052660
# 3     Sukesh M  100315 2021-01-03    Urban    NY     East      17580000
# 4     deepak m  100385 2021-01-03    Urban    NY     East       1925000
# 5    sudeesh r  100388 2021-01-04    Urban    IL  Midwest      12934500
# 6     Sundar p  100358 2021-01-05    Urban    WI  Midwest        928300
# 7      Vilas M  100264 2021-01-07    Rural    NY     East       2219900
# 8     Basava P  100265 2021-01-07    Urban    NY     East      14100000
# 9     Rajesh K  100357 2021-01-08    Urban    NY     East       4762808
#
#   Construction BusinessType Earthquake Flood
# 0        Frame       Retail          N     N
# 1  Fire Resist    Apartment          Y     Y
# 2        Frame      Farming          N     N
# 3        Frame    Apartment          Y     Y
# 4      Masonry  Hospitality          N     N
# 5        Frame    Apartment          Y     Y
# 6      Masonry  Office Bldg          N     N
# 7        Frame      Farming          N     N
# 8        Frame    Apartment          Y     Y
# 9      Masonry        Other          Y     Y

# %%
df.columns
# Out:
# Index(['Column1', 'Policy', 'Expiry', 'Location', 'State', 'Region',
#        'InsuredValue', 'Construction', 'BusinessType', 'Earthquake', 'Flood'],
#       dtype='object')

# %%
df.drop(columns='Region')
# Out:
#         Column1  Policy     Expiry Location State  InsuredValue Construction  \
# 0   Rahul Kumar  100242 2021-01-02    Urban    NY       1617630        Frame
# 1   Rohan Singh  100314 2021-01-02    Urban    NY       8678500  Fire Resist
# 2     Karthik A  100359 2021-01-02    Rural    WI       2052660        Frame
# 3      Sukesh M  100315 2021-01-03    Urban    NY      17580000        Frame
# 4      deepak m  100385 2021-01-03    Urban    NY       1925000      Masonry
# ..          ...     ...        ...      ...   ...           ...          ...
# 95    sudeesh r  100467 2021-03-08    Urban    NJ       2249500        Frame
# 96     Sundar p  100583 2021-03-08    Urban    NY       7611000      Masonry
# 97      Vilas M  100404 2021-03-09    Rural    WI       1152600        Frame
# 98     Basava P  100554 2021-03-09    Urban    NJ       9115500        Frame
# 99     Rajesh K  100446 2021-03-11    Urban    NY       1600000      Masonry
#
#    BusinessType Earthquake Flood
# 0        Retail          N     N
# 1     Apartment          Y     Y
# 2       Farming          N     N
# 3     Apartment          Y     Y
# 4   Hospitality          N     N
# ..          ...        ...   ...
# 95      Farming          N     N
# 96  Office Bldg          Y     Y
# 97      Farming          N     N
# 98    Apartment          Y     Y
# 99  Hospitality          Y     Y
#
# [100 rows x 10 columns]

# %%
len(df)
# Out:
# 100

# %%
df.iloc[0:5,0:4]
# Out:
#        Column1  Policy     Expiry Location
# 0  Rahul Kumar  100242 2021-01-02    Urban
# 1  Rohan Singh  100314 2021-01-02    Urban
# 2    Karthik A  100359 2021-01-02    Rural
# 3     Sukesh M  100315 2021-01-03    Urban
# 4     deepak m  100385 2021-01-03    Urban

# %%
df.loc[[0,2,4],['Policy','Expiry','Location']]
# Out:
#    Policy     Expiry Location
# 0  100242 2021-01-02    Urban
# 2  100359 2021-01-02    Rural
# 4  100385 2021-01-03    Urban

# %%
df.dtypes
# Out:
# Column1                 object
# Policy                   int64
# Expiry          datetime64[ns]
# Location                object
# State                   object
# Region                  object
# InsuredValue             int64
# Construction            object
# BusinessType            object
# Earthquake              object
# Flood                   object
# dtype: object

# %%
df.sample(n=20)
# Out:
#            Column1  Policy     Expiry Location State     Region  InsuredValue  \
# 55       Praveen D  100371 2021-02-08    Urban    OH    Central        218490
# 54        Rajesh K  100509 2021-02-07    Urban    OH    Central       1849000
# 64        deepak m  100513 2021-02-13    Rural    NY       East       2937200
# 36        Sundar p  100310 2021-01-28    Urban    WI    Midwest       8800000
# 68        Basava P  100436 2021-02-17    Rural    NY       East       3805200
# 51        Sundar p  100413 2021-02-05    Urban    NY       East       8397700
# 7          Vilas M  100264 2021-01-07    Rural    NY       East       2219900
# 30     Rahul Kumar  100275 2021-01-25    Urban    WI    Midwest      53410614
# 80       sudeesh r  100367 2021-02-24    Urban    NH  Northeast       2500000
# 66        Sundar p  100471 2021-02-15    Urban    NY       East      13882500
# 13  Siddanth Patil  100441 2021-01-10    Urban    NJ       East        472800
# 50       sudeesh r  100309 2021-02-05    Urban    WI    Midwest       5000368
# 26        Sudeep J  100461 2021-01-20    Urban    WI    Midwest       4380200
# 21        Sundar p  100252 2021-01-17    Urban    OH    Central       1529600
# 42     Suraj Kumar  100415 2021-01-31    Urban    NY       East       9650000
# 46     Rohan Singh  100420 2021-02-02    Urban    NY       East       7577000
# 59  Omkar Pavtekar  100452 2021-02-09    Urban    NJ       East       5918400
# 22         Vilas M  100279 2021-01-18    Urban    NY       East       7677000
# 58  Siddanth Patil  100377 2021-02-09    Urban    NY       East      11400000
# 61     Rohan Singh  100325 2021-02-13    Urban    NY       East        140000
#
#    Construction   BusinessType Earthquake Flood
# 55        Frame      Apartment          N     N
# 54   Metal Clad         Retail          N     N
# 64        Frame        Farming          N     N
# 36  Fire Resist    Office Bldg          Y     Y
# 68   Metal Clad        Farming          N     N
# 51        Frame      Apartment          Y     Y
# 7         Frame        Farming          N     N
# 30        Frame   Construction          Y     Y
# 80   Metal Clad  Manufacturing          N     N
# 66        Frame      Apartment          Y     Y
# 13      Masonry         Retail          Y     Y
# 50      Masonry  Manufacturing          N     N
# 26      Masonry    Office Bldg          Y     Y
# 21      Masonry      Apartment          N     N
# 42        Frame    Office Bldg          Y     Y
# 46        Frame      Apartment          Y     Y
# 59        Frame        Farming          Y     N
# 22        Frame      Apartment          Y     Y
# 58      Masonry      Apartment          Y     Y
# 61      Masonry         Retail          N     N

# %%
df.Column1.unique()
# Out:
# array(['Rahul Kumar', 'Rohan Singh', 'Karthik A', 'Sukesh M', 'deepak m',
#        'sudeesh r', 'Sundar p', 'Vilas M', 'Basava P', 'Rajesh K',
#        'Praveen D', 'Sudeep J', 'Suraj Kumar', 'Siddanth Patil',
#        'Omkar Pavtekar'], dtype=object)

# %%
df.Column1.nunique()
# Out:
# 15

# %%
df.replace('Karthik A','Karthik')
# Out:
#         Column1  Policy     Expiry Location State   Region  InsuredValue  \
# 0   Rahul Kumar  100242 2021-01-02    Urban    NY     East       1617630
# 1   Rohan Singh  100314 2021-01-02    Urban    NY     East       8678500
# 2       Karthik  100359 2021-01-02    Rural    WI  Midwest       2052660
# 3      Sukesh M  100315 2021-01-03    Urban    NY     East      17580000
# 4      deepak m  100385 2021-01-03    Urban    NY     East       1925000
# ..          ...     ...        ...      ...   ...      ...           ...
# 95    sudeesh r  100467 2021-03-08    Urban    NJ     East       2249500
# 96     Sundar p  100583 2021-03-08    Urban    NY     East       7611000
# 97      Vilas M  100404 2021-03-09    Rural    WI  Midwest       1152600
# 98     Basava P  100554 2021-03-09    Urban    NJ     East       9115500
# 99     Rajesh K  100446 2021-03-11    Urban    NY     East       1600000
#
#    Construction BusinessType Earthquake Flood
# 0         Frame       Retail          N     N
# 1   Fire Resist    Apartment          Y     Y
# 2         Frame      Farming          N     N
# 3         Frame    Apartment          Y     Y
# 4       Masonry  Hospitality          N     N
# ..          ...          ...        ...   ...
# 95        Frame      Farming          N     N
# 96      Masonry  Office Bldg          Y     Y
# 97        Frame      Farming          N     N
# 98        Frame    Apartment          Y     Y
# 99      Masonry  Hospitality          Y     Y
#
# [100 rows x 11 columns]

# %%
df.rename(columns={"Column1":"Name"})
# Out:
#            Name  Policy     Expiry Location State   Region  InsuredValue  \
# 0   Rahul Kumar  100242 2021-01-02    Urban    NY     East       1617630
# 1   Rohan Singh  100314 2021-01-02    Urban    NY     East       8678500
# 2     Karthik A  100359 2021-01-02    Rural    WI  Midwest       2052660
# 3      Sukesh M  100315 2021-01-03    Urban    NY     East      17580000
# 4      deepak m  100385 2021-01-03    Urban    NY     East       1925000
# ..          ...     ...        ...      ...   ...      ...           ...
# 95    sudeesh r  100467 2021-03-08    Urban    NJ     East       2249500
# 96     Sundar p  100583 2021-03-08    Urban    NY     East       7611000
# 97      Vilas M  100404 2021-03-09    Rural    WI  Midwest       1152600
# 98     Basava P  100554 2021-03-09    Urban    NJ     East       9115500
# 99     Rajesh K  100446 2021-03-11    Urban    NY     East       1600000
#
#    Construction BusinessType Earthquake Flood
# 0         Frame       Retail          N     N
# 1   Fire Resist    Apartment          Y     Y
# 2         Frame      Farming          N     N
# 3         Frame    Apartment          Y     Y
# 4       Masonry  Hospitality          N     N
# ..          ...          ...        ...   ...
# 95        Frame      Farming          N     N
# 96      Masonry  Office Bldg          Y     Y
# 97        Frame      Farming          N     N
# 98        Frame    Apartment          Y     Y
# 99      Masonry  Hospitality          Y     Y
#
# [100 rows x 11 columns]

# %%
df.groupby(["State","Location"])["InsuredValue"].sum()
# Out:
# State  Location
# IL     Rural         3145700
#        Urban        14829500
# NH     Urban         2500000
# NJ     Urban        97321206
# NY     Rural        24987580
#        Urban       308083101
# OH     Urban        10761990
# VT     Rural         2985950
#        Urban         9636375
# WI     Rural        12959625
#        Urban       131588182
# Name: InsuredValue, dtype: int64

# %%
pd.crosstab(df['Region'],df['Location'])
# Out:
# Location   Rural  Urban
# Region
# Central        0      5
# East          11     59
# Midwest        6     15
# Northeast      1      3

# %%
df['InsuredValue'].describe()
# Out:
# count    1.000000e+02
# mean     6.187992e+06
# std      7.590561e+06
# min      8.200000e+04
# 25%      1.749414e+06
# 50%      3.099150e+06
# 75%      8.708875e+06
# max      5.341061e+07
# Name: InsuredValue, dtype: float64

# %%
df.nlargest(5,"InsuredValue")
# Out:
#         Column1  Policy     Expiry Location State   Region  InsuredValue  \
# 30  Rahul Kumar  100275 2021-01-25    Urban    WI  Midwest      53410614
# 52      Vilas M  100498 2021-02-06    Urban    NJ     East      36356000
# 40    Praveen D  100291 2021-01-29    Urban    NY     East      21400000
# 39     Rajesh K  100290 2021-01-29    Urban    NY     East      18933000
# 35    sudeesh r  100379 2021-01-26    Urban    NY     East      18777355
#
#    Construction  BusinessType Earthquake Flood
# 30        Frame  Construction          Y     Y
# 52  Fire Resist     Apartment          Y     Y
# 40  Fire Resist     Apartment          Y     Y
# 39        Frame   Office Bldg          Y     Y
# 35        Frame     Apartment          Y     Y

# %%
df.nsmallest(5,"InsuredValue")
# Out:
#         Column1  Policy     Expiry Location State   Region  InsuredValue  \
# 17    Karthik A  100280 2021-01-15    Urban    NY     East         82000
# 61  Rohan Singh  100325 2021-02-13    Urban    NY     East        140000
# 18     Sukesh M  100424 2021-01-16    Urban    NY     East        192000
# 55    Praveen D  100371 2021-02-08    Urban    OH  Central        218490
# 93     Sukesh M  100532 2021-03-07    Urban    NJ     East        296000
#
#    Construction  BusinessType Earthquake Flood
# 17      Masonry  Organization          Y     Y
# 61      Masonry        Retail          N     N
# 18      Masonry        Retail          N     N
# 55        Frame     Apartment          N     N
# 93        Frame     Apartment          N     N

# %%
df.explode('Construction')
# Out:
#         Column1  Policy     Expiry Location State   Region  InsuredValue  \
# 0   Rahul Kumar  100242 2021-01-02    Urban    NY     East       1617630
# 1   Rohan Singh  100314 2021-01-02    Urban    NY     East       8678500
# 2     Karthik A  100359 2021-01-02    Rural    WI  Midwest       2052660
# 3      Sukesh M  100315 2021-01-03    Urban    NY     East      17580000
# 4      deepak m  100385 2021-01-03    Urban    NY     East       1925000
# ..          ...     ...        ...      ...   ...      ...           ...
# 95    sudeesh r  100467 2021-03-08    Urban    NJ     East       2249500
# 96     Sundar p  100583 2021-03-08    Urban    NY     East       7611000
# 97      Vilas M  100404 2021-03-09    Rural    WI  Midwest       1152600
# 98     Basava P  100554 2021-03-09    Urban    NJ     East       9115500
# 99     Rajesh K  100446 2021-03-11    Urban    NY     East       1600000
#
#    Construction BusinessType Earthquake Flood
# 0         Frame       Retail          N     N
# 1   Fire Resist    Apartment          Y     Y
# 2         Frame      Farming          N     N
# 3         Frame    Apartment          Y     Y
# 4       Masonry  Hospitality          N     N
# ..          ...          ...        ...   ...
# 95        Frame      Farming          N     N
# 96      Masonry  Office Bldg          Y     Y
# 97        Frame      Farming          N     N
# 98        Frame    Apartment          Y     Y
# 99      Masonry  Hospitality          Y     Y
#
# [100 rows x 11 columns]

# %%
df.drop_duplicates("Column1")
# Out:
#            Column1  Policy     Expiry Location State   Region  InsuredValue  \
# 0      Rahul Kumar  100242 2021-01-02    Urban    NY     East       1617630
# 1      Rohan Singh  100314 2021-01-02    Urban    NY     East       8678500
# 2        Karthik A  100359 2021-01-02    Rural    WI  Midwest       2052660
# 3         Sukesh M  100315 2021-01-03    Urban    NY     East      17580000
# 4         deepak m  100385 2021-01-03    Urban    NY     East       1925000
# 5        sudeesh r  100388 2021-01-04    Urban    IL  Midwest      12934500
# 6         Sundar p  100358 2021-01-05    Urban    WI  Midwest        928300
# 7          Vilas M  100264 2021-01-07    Rural    NY     East       2219900
# 8         Basava P  100265 2021-01-07    Urban    NY     East      14100000
# 9         Rajesh K  100357 2021-01-08    Urban    NY     East       4762808
# 10       Praveen D  100399 2021-01-08    Urban    NY     East      13925190
# 11        Sudeep J  100329 2021-01-09    Urban    NY     East       6350000
# 12     Suraj Kumar  100429 2021-01-09    Urban    WI  Midwest       4036000
# 13  Siddanth Patil  100441 2021-01-10    Urban    NJ     East        472800
# 14  Omkar Pavtekar  100442 2021-01-10    Urban    WI  Midwest      11710880
#
#    Construction BusinessType Earthquake Flood
# 0         Frame       Retail          N     N
# 1   Fire Resist    Apartment          Y     Y
# 2         Frame      Farming          N     N
# 3         Frame    Apartment          Y     Y
# 4       Masonry  Hospitality          N     N
# 5         Frame    Apartment          Y     Y
# 6       Masonry  Office Bldg          N     N
# 7         Frame      Farming          N     N
# 8         Frame    Apartment          Y     Y
# 9       Masonry        Other          Y     Y
# 10        Frame    Apartment          Y     Y
# 11        Frame    Apartment          Y     Y
# 12      Masonry      Medical          Y     Y
# 13      Masonry       Retail          Y     Y
# 14      Masonry    Apartment          Y     Y

# %%
df['Earthquake'] = df['Earthquake'].astype('category')

# %%
df['Earthquake'] = df['Earthquake'].cat.rename_categories({'Y': "Yes", 'N': "No"})

# %%
df.to_string("Flood")

# %%
df
# Out:
#         Column1  Policy     Expiry Location State   Region  InsuredValue  \
# 0   Rahul Kumar  100242 2021-01-02    Urban    NY     East       1617630
# 1   Rohan Singh  100314 2021-01-02    Urban    NY     East       8678500
# 2     Karthik A  100359 2021-01-02    Rural    WI  Midwest       2052660
# 3      Sukesh M  100315 2021-01-03    Urban    NY     East      17580000
# 4      deepak m  100385 2021-01-03    Urban    NY     East       1925000
# ..          ...     ...        ...      ...   ...      ...           ...
# 95    sudeesh r  100467 2021-03-08    Urban    NJ     East       2249500
# 96     Sundar p  100583 2021-03-08    Urban    NY     East       7611000
# 97      Vilas M  100404 2021-03-09    Rural    WI  Midwest       1152600
# 98     Basava P  100554 2021-03-09    Urban    NJ     East       9115500
# 99     Rajesh K  100446 2021-03-11    Urban    NY     East       1600000
#
#    Construction BusinessType Earthquake Flood
# 0         Frame       Retail         No   NaN
# 1   Fire Resist    Apartment        Yes   NaN
# 2         Frame      Farming         No   NaN
# 3         Frame    Apartment        Yes   NaN
# 4       Masonry  Hospitality         No   NaN
# ..          ...          ...        ...   ...
# 95        Frame      Farming         No   NaN
# 96      Masonry  Office Bldg        Yes   NaN
# 97        Frame      Farming         No   NaN
# 98        Frame    Apartment        Yes   NaN
# 99      Masonry  Hospitality        Yes   NaN
#
# [100 rows x 11 columns]

# %%
df['Column1'].str.split(' ', expand=True)
# Out:
#           0      1
# 0     Rahul  Kumar
# 1     Rohan  Singh
# 2   Karthik      A
# 3    Sukesh      M
# 4    deepak      m
# ..      ...    ...
# 95  sudeesh      r
# 96   Sundar      p
# 97    Vilas      M
# 98   Basava      P
# 99   Rajesh      K
#
# [100 rows x 2 columns]

# %%
df['Column1'].str.capitalize()
# Out:
# 0     Rahul kumar
# 1     Rohan singh
# 2       Karthik a
# 3        Sukesh m
# 4        Deepak m
#          ...
# 95      Sudeesh r
# 96       Sundar p
# 97        Vilas m
# 98       Basava p
# 99       Rajesh k
# Name: Column1, Length: 100, dtype: object

# %%
df
# Out:
#         Column1  Policy     Expiry Location State   Region  InsuredValue  \
# 0   RAHUL KUMAR  100242 2021-01-02    Urban    NY     East       1617630
# 1   ROHAN SINGH  100314 2021-01-02    Urban    NY     East       8678500
# 2     KARTHIK A  100359 2021-01-02    Rural    WI  Midwest       2052660
# 3      SUKESH M  100315 2021-01-03    Urban    NY     East      17580000
# 4      DEEPAK M  100385 2021-01-03    Urban    NY     East       1925000
# ..          ...     ...        ...      ...   ...      ...           ...
# 95    SUDEESH R  100467 2021-03-08    Urban    NJ     East       2249500
# 96     SUNDAR P  100583 2021-03-08    Urban    NY     East       7611000
# 97      VILAS M  100404 2021-03-09    Rural    WI  Midwest       1152600
# 98     BASAVA P  100554 2021-03-09    Urban    NJ     East       9115500
# 99     RAJESH K  100446 2021-03-11    Urban    NY     East       1600000
#
#    Construction BusinessType Earthquake Flood
# 0         Frame       Retail         No   NaN
# 1   Fire Resist    Apartment        Yes   NaN
# 2         Frame      Farming         No   NaN
# 3         Frame    Apartment        Yes   NaN
# 4       Masonry  Hospitality         No   NaN
# ..          ...          ...        ...   ...
# 95        Frame      Farming         No   NaN
# 96      Masonry  Office Bldg        Yes   NaN
# 97        Frame      Farming         No   NaN
# 98        Frame    Apartment        Yes   NaN
# 99      Masonry  Hospitality        Yes   NaN
#
# [100 rows x 11 columns]

# %%
df=df['Column1'].str.split(' ', expand=True)

# %%
df
# Out:
#           0      1
# 0     RAHUL  KUMAR
# 1     ROHAN  SINGH
# 2   KARTHIK      A
# 3    SUKESH      M
# 4    DEEPAK      M
# ..      ...    ...
# 95  SUDEESH      R
# 96   SUNDAR      P
# 97    VILAS      M
# 98   BASAVA      P
# 99   RAJESH      K
#
# [100 rows x 2 columns]

# %%
d=df.rename(columns={0:"First_Name",1:"Last_Name"})

# %%
df
# Out:
#         Column1  Policy     Expiry Location State   Region  InsuredValue  \
# 0   Rahul Kumar  100242 2021-01-02    Urban    NY     East       1617630
# 1   Rohan Singh  100314 2021-01-02    Urban    NY     East       8678500
# 2     Karthik A  100359 2021-01-02    Rural    WI  Midwest       2052660
# 3      Sukesh M  100315 2021-01-03    Urban    NY     East      17580000
# 4      deepak m  100385 2021-01-03    Urban    NY     East       1925000
# ..          ...     ...        ...      ...   ...      ...           ...
# 95    sudeesh r  100467 2021-03-08    Urban    NJ     East       2249500
# 96     Sundar p  100583 2021-03-08    Urban    NY     East       7611000
# 97      Vilas M  100404 2021-03-09    Rural    WI  Midwest       1152600
# 98     Basava P  100554 2021-03-09    Urban    NJ     East       9115500
# 99     Rajesh K  100446 2021-03-11    Urban    NY     East       1600000
#
#    Construction BusinessType Earthquake Flood
# 0         Frame       Retail          N     N
# 1   Fire Resist    Apartment          Y     Y
# 2         Frame      Farming          N     N
# 3         Frame    Apartment          Y     Y
# 4       Masonry  Hospitality          N     N
# ..          ...          ...        ...   ...
# 95        Frame      Farming          N     N
# 96      Masonry  Office Bldg          Y     Y
# 97        Frame      Farming          N     N
# 98        Frame    Apartment          Y     Y
# 99      Masonry  Hospitality          Y     Y
#
# [100 rows x 11 columns]

# %%
df["State"].sort_values(ascending = True)
# Out:
# 49    IL
# 5     IL
# 32    IL
# 80    NH
# 44    NJ
#       ..
# 70    WI
# 26    WI
# 33    WI
# 12    WI
# 73    WI
# Name: State, Length: 100, dtype: object

# %%
df.sort_values(by=["Policy", "State", "Region"],ascending=[True, True, False])
# Out:
#            Column1  Policy     Expiry Location State   Region  InsuredValue  \
# 0      Rahul Kumar  100242 2021-01-02    Urban    NY     East       1617630
# 21        Sundar p  100252 2021-01-17    Urban    OH  Central       1529600
# 27     Suraj Kumar  100263 2021-01-22    Urban    NJ     East       2815000
# 7          Vilas M  100264 2021-01-07    Rural    NY     East       2219900
# 8         Basava P  100265 2021-01-07    Urban    NY     East      14100000
# ..             ...     ...        ...      ...   ...      ...           ...
# 78        Sukesh M  100537 2021-02-22    Urban    NY     East       9493313
# 85       Praveen D  100546 2021-02-27    Rural    NY     East       1498850
# 98        Basava P  100554 2021-03-09    Urban    NJ     East       9115500
# 89  Omkar Pavtekar  100566 2021-03-02    Urban    OH  Central       5377000
# 96        Sundar p  100583 2021-03-08    Urban    NY     East       7611000
#
#    Construction BusinessType Earthquake Flood
# 0         Frame       Retail          N     N
# 21      Masonry    Apartment          N     N
# 27   Metal Clad    Apartment          Y     Y
# 7         Frame      Farming          N     N
# 8         Frame    Apartment          Y     Y
# ..          ...          ...        ...   ...
# 78      Masonry    Apartment          Y     Y
# 85   Metal Clad      Farming          N     N
# 98        Frame    Apartment          Y     Y
# 89        Frame    Apartment          Y     Y
# 96      Masonry  Office Bldg          Y     Y
#
# [100 rows x 11 columns]

# %%
s=df["State"].value_counts().sort_values(ascending=False).head(10)

# %%
s
# Out:
# NY    52
# WI    18
# NJ    18
# OH     5
# IL     3
# VT     3
# NH     1
# Name: State, dtype: int64

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns 
from matplotlib import style 
import datetime as dt
style.use("ggplot")

# %%
s.plot.bar()
plt.xlabel("States")
plt.ylabel("Number of Policies")
plt.title("Number of Policies Provided by State")
plt.tight_layout()
plt.margins(0.05)
